# %% [markdown]
# ## Pandas Dataframe
# #### It is a 2-dimensional labeled data structure with columns of potentially different types.

# %% [markdown]
# ### You can check out the Dataframe documentation through this  [link](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html).

# %% [markdown]
# ### Introduction:
# ###### We will use a very popular dataset from University of California Irvine.[link](http://archive.ics.uci.edu/ml/datasets/Bank+Marketing)
#
# ### Step 1. Import the necessary libraries - pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [link](https://raw.githubusercontent.com/Sketchjar/Datasets/master/bank-full.csv). This is CSV file.

# %%
url = 'https://raw.githubusercontent.com/Sketchjar/Datasets/master/bank-full.csv'

# %%
df = pd.read_csv(url,sep=';')

# %%
df.head(20)
# Out:
#     age           job   marital  education default  balance housing loan  \
# 0    58    management   married   tertiary      no     2143     yes   no
# 1    44    technician    single  secondary      no       29     yes   no
# 2    33  entrepreneur   married  secondary      no        2     yes  yes
# 3    47   blue-collar   married    unknown      no     1506     yes   no
# 4    33       unknown    single    unknown      no        1      no   no
# 5    35    management   married   tertiary      no      231     yes   no
# 6    28    management    single   tertiary      no      447     yes  yes
# 7    42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 8    58       retired   married    primary      no      121     yes   no
# 9    43    technician    single  secondary      no      593     yes   no
# 10   41        admin.  divorced  secondary      no      270     yes   no
# 11   29        admin.    single  secondary      no      390     yes   no
# ...

# %%
df.tail(10)
# Out:
#        age           job   marital  education default  balance housing loan  \
# 45201   53    management   married   tertiary      no      583      no   no
# 45202   34        admin.    single  secondary      no      557      no   no
# 45203   23       student    single   tertiary      no      113      no   no
# 45204   73       retired   married  secondary      no     2850      no   no
# 45205   25    technician    single  secondary      no      505      no  yes
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
df['education'].dtype
# Out:
# dtype('O')

# %%
df.shape
# Out:
# (45211, 17)

# %%
df.size
# Out:
# 768587

# %%
45211*17
# Out:
# 768587

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=45211, step=1),
#  Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#         'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#         'previous', 'poutcome', 'y'],
#        dtype='object')]

# %%
df.ndim
# Out:
# 2

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
df[['job','marital']]
# Out:
#                  job   marital
# 0         management   married
# 1         technician    single
# 2       entrepreneur   married
# 3        blue-collar   married
# 4            unknown    single
# 5         management   married
# 6         management    single
# 7       entrepreneur  divorced
# 8            retired   married
# 9         technician    single
# 10            admin.  divorced
# 11            admin.    single
# 12        technician   married
# 13        technician   married
# 14          services   married
# 15           retired   married
# 16            admin.    single
# 17       blue-collar   married
# 18           retired   married
# 19          services   married
# 20       blue-collar   married
# 21        management   married
# 22       blue-collar    single
# 23          services   married
# 24           retired   married
# 25            admin.   married
# 26        management    single
# 27      entrepreneur   married
# 28        management    single
# ...

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
df['new_age'] = df['age'] / 2

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y  \
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no
#
#    new_age
# 0     29.0
# 1     22.0
# 2     16.5
# 3     23.5
# 4     16.5

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous       new_age
# count  45211.000000  45211.000000  45211.000000
# mean      40.197828      0.580323     20.468105
# std      100.128746      2.303441      5.309381
# min       -1.000000      0.000000      9.000000
# ...

# %%
df.describe(include='all')
# Out:
#                  age          job  marital  education default        balance  \
# count   45211.000000        45211    45211      45211   45211   45211.000000
# unique           NaN           12        3          4       2            NaN
# top              NaN  blue-collar  married  secondary      no            NaN
# freq             NaN         9732    27214      23202   44396            NaN
# mean       40.936210          NaN      NaN        NaN     NaN    1362.272058
# std        10.618762          NaN      NaN        NaN     NaN    3044.765829
# min        18.000000          NaN      NaN        NaN     NaN   -8019.000000
# 25%        33.000000          NaN      NaN        NaN     NaN      72.000000
# 50%        39.000000          NaN      NaN        NaN     NaN     448.000000
# 75%        48.000000          NaN      NaN        NaN     NaN    1428.000000
# max        95.000000          NaN      NaN        NaN     NaN  102127.000000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 18 columns):
# age          45211 non-null int64
# job          45211 non-null object
# marital      45211 non-null object
# education    45211 non-null object
# default      45211 non-null object
# balance      45211 non-null int64
# housing      45211 non-null object
# loan         45211 non-null object
# contact      45211 non-null object
# day          45211 non-null int64
# month        45211 non-null object
# duration     45211 non-null int64
# campaign     45211 non-null int64
# pdays        45211 non-null int64
# previous     45211 non-null int64
# poutcome     45211 non-null object
# y            45211 non-null object
# new_age      45211 non-null float64
# dtypes: float64(1), int64(7), object(10)
# memory usage: 6.2+ MB

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y  \
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no
#
#    new_age
# 0     29.0
# 1     22.0
# 2     16.5
# 3     23.5
# 4     16.5

# %%
df['age'].mean()
# Out:
# 40.93621021432837

# %%
df['age'].var()
# Out:
# 112.75810728286069

# %%
df['age'].max()
# Out:
# 95

# %%
df['age'].min()
# Out:
# 18

# %%
df['age'].std()
# Out:
# 10.618762040975431

# %%
df['age'].sem()
# Out:
# 0.04994037879539488

# %%
df['age'].kurt()
# Out:
# 0.3195703759105042

# %%
df['age'].skew()
# Out:
# 0.6848179257252598

# %%
df.sample(20)
# Out:
#        age            job   marital  education default  balance housing loan  \
# 8395    51     management   married   tertiary      no     1355     yes   no
# 217     53     unemployed   married    unknown      no       13      no   no
# 17185   55   entrepreneur   married  secondary      no      814      no  yes
# 40987   76        retired   married    primary      no     3324      no   no
# 16369   29      housemaid   married    primary      no      417      no   no
# 11809   48     management   married  secondary      no     3260      no   no
# 40566   34    blue-collar    single    primary      no       79      no   no
# 7507    58    blue-collar   married  secondary      no     1298     yes   no
# 13198   36     unemployed   married  secondary      no      356      no   no
# 22337   58       services  divorced  secondary      no      183      no   no
# 44636   45       services  divorced    primary      no      523      no   no
# ...

# %%
df['age'].sum()
# Out:
# 1850767

# %%
df.iloc[5]
# Out:
# age                  35
# job          management
# marital         married
# education      tertiary
# default              no
# balance             231
# housing             yes
# loan                 no
# contact         unknown
# day                   5
# month               may
# duration            139
# campaign              1
# pdays                -1
# previous              0
# poutcome        unknown
# y                    no
# new_age            17.5
# Name: 5, dtype: object

# %%
df.iloc[-1]
# Out:
# age                    37
# job          entrepreneur
# marital           married
# education       secondary
# default                no
# balance              2971
# housing                no
# loan                   no
# contact          cellular
# day                    17
# month                 nov
# duration              361
# campaign                2
# pdays                 188
# previous               11
# poutcome            other
# y                      no
# new_age              18.5
# Name: 45210, dtype: object

# %%
df.iloc[:,1]
# Out:
# 0           management
# 1           technician
# 2         entrepreneur
# 3          blue-collar
# 4              unknown
# 5           management
# 6           management
# 7         entrepreneur
# 8              retired
# 9           technician
# 10              admin.
# 11              admin.
# 12          technician
# 13          technician
# 14            services
# 15             retired
# 16              admin.
# 17         blue-collar
# 18             retired
# 19            services
# 20         blue-collar
# 21          management
# 22         blue-collar
# 23            services
# 24             retired
# 25              admin.
# 26          management
# 27        entrepreneur
# 28          management
# 29          technician
#              ...
# 45181      blue-collar
# 45182       technician
# 45183          retired
# 45184          retired
# 45185         services
# 45186          unknown
# 45187         services
# 45188       management
# 45189         services
# ...

# %%
df.iloc[:,-1]
# Out:
# 0        29.0
# 1        22.0
# 2        16.5
# 3        23.5
# 4        16.5
# 5        17.5
# 6        14.0
# 7        21.0
# 8        29.0
# 9        21.5
# 10       20.5
# 11       14.5
# 12       26.5
# 13       29.0
# 14       28.5
# 15       25.5
# 16       22.5
# 17       28.5
# 18       30.0
# 19       16.5
# 20       14.0
# 21       28.0
# 22       16.0
# 23       12.5
# 24       20.0
# 25       22.0
# 26       19.5
# 27       26.0
# 28       23.0
# 29       18.0
#          ...
# 45181    23.0
# 45182    17.0
# 45183    35.0
# 45184    31.5
# 45185    30.0
# 45186    29.5
# 45187    16.0
# 45188    14.5
# 45189    12.5
# 45190    16.0
# 45191    37.5
# 45192    14.5
# 45193    14.0
# 45194    29.5
# 45195    34.0
# 45196    12.5
# 45197    18.0
# 45198    18.5
# 45199    17.0
# 45200    19.0
# 45201    26.5
# 45202    17.0
# 45203    11.5
# 45204    36.5
# 45205    12.5
# 45206    25.5
# 45207    35.5
# 45208    36.0
# 45209    28.5
# 45210    18.5
# ...

# %%
df.iloc[0:10]
# Out:
#    age           job   marital  education default  balance housing loan  \
# 0   58    management   married   tertiary      no     2143     yes   no
# 1   44    technician    single  secondary      no       29     yes   no
# 2   33  entrepreneur   married  secondary      no        2     yes  yes
# 3   47   blue-collar   married    unknown      no     1506     yes   no
# 4   33       unknown    single    unknown      no        1      no   no
# 5   35    management   married   tertiary      no      231     yes   no
# 6   28    management    single   tertiary      no      447     yes  yes
# 7   42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 8   58       retired   married    primary      no      121     yes   no
# 9   43    technician    single  secondary      no      593     yes   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y  \
# 0  unknown    5   may       261         1     -1         0  unknown  no
# ...

# %%
df.iloc[:,0:2]
# Out:
#        age            job
# 0       58     management
# 1       44     technician
# 2       33   entrepreneur
# 3       47    blue-collar
# 4       33        unknown
# 5       35     management
# 6       28     management
# 7       42   entrepreneur
# 8       58        retired
# 9       43     technician
# 10      41         admin.
# 11      29         admin.
# 12      53     technician
# 13      58     technician
# 14      57       services
# 15      51        retired
# 16      45         admin.
# 17      57    blue-collar
# 18      60        retired
# 19      33       services
# 20      28    blue-collar
# 21      56     management
# 22      32    blue-collar
# 23      25       services
# 24      40        retired
# 25      44         admin.
# 26      39     management
# 27      52   entrepreneur
# 28      46     management
# 29      36     technician
# ...    ...            ...
# 45181   46    blue-collar
# 45182   34     technician
# 45183   70        retired
# ...

# %%
df.iloc[1:3,0:2]
# Out:
#    age           job
# 1   44    technician
# 2   33  entrepreneur

# %%
df.iloc[[0,5],[1,3]]
# Out:
#           job education
# 0  management  tertiary
# 5  management  tertiary

# %%
df.iloc[10:20,[0,3,4,5]]
# Out:
#     age  education default  balance
# 10   41  secondary      no      270
# 11   29  secondary      no      390
# 12   53  secondary      no        6
# 13   58    unknown      no       71
# 14   57  secondary      no      162
# 15   51    primary      no      229
# 16   45    unknown      no       13
# 17   57    primary      no       52
# 18   60    primary      no       60
# 19   33  secondary      no        0

# %%
df.loc[5]
# Out:
# age                  35
# job          management
# marital         married
# education      tertiary
# default              no
# balance             231
# housing             yes
# loan                 no
# contact         unknown
# day                   5
# month               may
# duration            139
# campaign              1
# pdays                -1
# previous              0
# poutcome        unknown
# y                    no
# new_age            17.5
# Name: 5, dtype: object

# %%
pd.crosstab(df.education,df.marital,margins=True)
# Out:
# marital    divorced  married  single    All
# education
# primary         752     5246     853   6851
# secondary      2815    13770    6617  23202
# tertiary       1471     7038    4792  13301
# unknown         169     1160     528   1857
# All            5207    27214   12790  45211

# %%
pd.crosstab([df.education,df.marital],df.housing,margins=True)
# Out:
# housing                no    yes    All
# education marital
# primary   divorced    386    366    752
#           married    2222   3024   5246
#           single      349    504    853
# secondary divorced   1111   1704   2815
#           married    5339   8431  13770
#           single     2714   3903   6617
# tertiary  divorced    718    753   1471
#           married    3702   3336   7038
#           single     2503   2289   4792
# unknown   divorced     85     84    169
#           married     630    530   1160
#           single      322    206    528
# All                 20081  25130  45211

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y  \
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no
#
#    new_age
# 0     29.0
# 1     22.0
# 2     16.5
# 3     23.5
# 4     16.5

# %%
df.pivot_table(values='balance',index=['job','marital'],columns=['education'],aggfunc='median')
# Out:
# education               primary  secondary  tertiary  unknown
# job           marital
# admin.        divorced    429.0      340.0     228.5    630.0
#               married     343.0      422.0     344.0    892.0
#               single      233.5      376.0     538.5    263.5
# blue-collar   divorced    214.0      251.0    1964.5    170.0
#               married     400.0      441.0     653.5    436.5
#               single      335.5      322.0     573.0    484.0
# entrepreneur  divorced     29.0      186.0     321.0   1209.0
#               married     491.5      330.0     425.0    345.0
#               single      103.0      318.0     303.0    323.0
# housemaid     divorced    497.0      221.0    1427.0   2015.0
#               married     311.0      436.0     451.5    909.0
#               single      387.5      650.0     608.0   3435.5
# management    divorced    173.5      283.0     432.0    582.0
#               married     595.0      478.0     620.5    914.0
# ...

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y  \
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no
#
#    new_age
# 0     29.0
# 1     22.0
# 2     16.5
# 3     23.5
# 4     16.5

# %%
df.groupby(['job'])['age'].mean()
# Out:
# job
# admin.           39.289886
# blue-collar      40.044081
# entrepreneur     42.190989
# housemaid        46.415323
# management       40.449567
# retired          61.626767
# self-employed    40.484484
# services         38.740250
# student          26.542644
# technician       39.314598
# unemployed       40.961627
# unknown          47.593750
# Name: age, dtype: float64

# %%
df.groupby(['job'])['balance'].sum()
# Out:
# job
# admin.            5873423
# blue-collar      10499141
# entrepreneur      2262426
# housemaid         1726570
# management       16680288
# retired           4492263
# self-employed     2602146
# services          4141904
# student           1302001
# technician        9516246
# unemployed        1982835
# unknown            510439
# Name: balance, dtype: int64

# %%
df.groupby(['job'])['balance'].max()
# Out:
# job
# admin.            64343
# blue-collar       66653
# entrepreneur      59649
# housemaid         45141
# management       102127
# retired           81204
# self-employed     52587
# services          57435
# student           24025
# technician        45248
# unemployed        44134
# unknown           19706
# Name: balance, dtype: int64

# %%
df.groupby(['job'])['balance'].min()
# Out:
# job
# admin.          -1601
# blue-collar     -8019
# entrepreneur    -2082
# housemaid       -1941
# management      -6847
# retired         -1598
# self-employed   -3313
# services        -2122
# student          -679
# technician      -2827
# unemployed      -1270
# unknown          -295
# Name: balance, dtype: int64

# %%
df.groupby(['education','job'])['balance'].sum()
# Out:
# education  job
# primary    admin.             194470
#            blue-collar       4081580
#            entrepreneur       307324
#            housemaid          707420
#            management         491640
#            retired           1494239
#            self-employed      172994
#            services           333467
#            student             54715
#            technician         234981
#            unemployed         408165
#            unknown             89263
# secondary  admin.            4708657
#            blue-collar       5714177
#            entrepreneur       580396
#            housemaid          570218
#            management        1487048
#            retired           2028145
#            self-employed      742616
#            services          3311338
#            student            640031
#            technician        5881175
#            unemployed        1043027
#            unknown             88716
# tertiary   admin.             696569
# ...

# %%
df.groupby(['education','job'])['balance','age'].mean().sort_values(by='education')
# Out:
#                              balance        age
# education job
# primary   admin.          930.478469  46.100478
#           unknown        1750.254902  47.000000
#           unemployed     1588.190661  43.073930
#           technician     1487.221519  47.189873
#           services        966.571014  43.756522
#           self-employed  1330.723077  45.276923
#           student        1243.522727  22.636364
#           management     1672.244898  48.605442
#           housemaid      1128.261563  48.631579
#           entrepreneur   1679.366120  44.360656
#           blue-collar    1086.104311  42.294838
#           retired        1879.545912  62.698113
# secondary services        957.864623  38.238068
#           unemployed     1432.729396  41.409341
#           technician     1124.722700  39.576975
#           student        1259.903543  25.779528
#           self-employed  1287.029463  41.537262
#           unknown        1249.521127  44.436620
# ...

# %%
df_sorted = df.sort_values(by='job',ascending=False)

# %%
df_sorted.head()
# Out:
#        age      job  marital  education default  balance housing loan  \
# 40109   60  unknown  married    unknown      no     5003      no   no
# 41542   38  unknown   single   tertiary      no        0      no   no
# 11666   57  unknown  married    unknown      no     2266      no   no
# 28117   48  unknown  married  secondary      no      438      no   no
# 18849   52  unknown  married    unknown      no     1571      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# 40109  telephone    4   jun       125         5     -1         0  unknown
# 41542   cellular   11   sep       260         3     95         3  success
# 11666    unknown   20   jun        42         5     -1         0  unknown
# 28117   cellular   28   jan       412         5     -1         0  unknown
# 18849   cellular    4   aug       164         1     -1         0  unknown
#
#          y  new_age
# 40109   no     30.0
# 41542  yes     19.0
# 11666   no     28.5
# ...

# %%
df_sorted = df.sort_values(by='job',ascending=True)

# %%
df_sorted
# Out:
#        age      job   marital  education default  balance housing loan  \
# 37155   53   admin.    single  secondary      no      233     yes   no
# 12015   39   admin.   married    unknown      no      378      no   no
# 25583   52   admin.   married    primary      no     6286      no   no
# 25582   54   admin.   married  secondary      no     3136     yes   no
# 12021   36   admin.    single  secondary      no      449     yes   no
# 36403   41   admin.   married  secondary      no      542     yes   no
# 36408   46   admin.  divorced  secondary      no      875     yes  yes
# 12023   40   admin.    single  secondary      no      142      no  yes
# 25574   30   admin.   married  secondary      no      521     yes   no
# 36416   30   admin.    single   tertiary      no        0     yes   no
# 5289    37   admin.   married  secondary      no      525     yes   no
# 12028   55   admin.  divorced  secondary      no      166      no   no
# ...

# %%
df_sorted.reset_index(inplace=True)

# %%
df_sorted.head()
# Out:
#    index  age     job  marital  education default  balance housing loan  \
# 0  37155   53  admin.   single  secondary      no      233     yes   no
# 1  12015   39  admin.  married    unknown      no      378      no   no
# 2  25583   52  admin.  married    primary      no     6286      no   no
# 3  25582   54  admin.  married  secondary      no     3136     yes   no
# 4  12021   36  admin.   single  secondary      no      449     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome   y  \
# 0   cellular   13   may       101         1     -1         0  unknown  no
# 1    unknown   20   jun        17         5     -1         0  unknown  no
# 2   cellular   19   nov       288         1     -1         0  unknown  no
# 3  telephone   19   nov        72         1     -1         0  unknown  no
# 4    unknown   20   jun       136         3     -1         0  unknown  no
#
#    new_age
# 0     26.5
# 1     19.5
# 2     26.0
# 3     27.0
# 4     18.0

# %%
pd.
